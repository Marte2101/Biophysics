# %%
import sys
# !{sys.executable} -m pip install numpy
# !{sys.executable} -m pip install matplotlib

# %%
import numpy as np
import matplotlib.pyplot as plt

x, data = np.loadtxt('tutorial_gromacs/alanine_dip/potential.xvg',comments=["#", "@"], unpack = True)

# %%
plt.plot(x, data)
print(data)
# Out:
# [  8501.895508   -469.897461 -10323.233398 -16359.501953 -20729.046875
#  -23812.958984 -24130.375    -24800.179688 -25316.076172 -25636.394531
#  -26158.664062 -26404.117188 -26586.955078 -26788.542969 -26873.25
#  -26993.359375 -27462.173828 -27656.652344 -28312.6875   -28372.462891
#  -28531.714844 -28696.296875 -28790.320312 -28966.382812 -29077.958984
#  -29150.605469 -29280.744141 -29377.966797 -29458.859375 -29556.863281
#  -29581.691406 -29667.90625  -29810.523438 -29866.681641 -30066.085938
#  -30121.357422 -30178.144531 -30207.421875 -30257.501953 -30382.878906
#  -30448.378906 -30593.539062 -30645.279297 -30673.603516 -30726.550781
#  -30802.466797 -30857.882812 -30944.400391 -30990.611328 -31022.068359
#  -31074.228516 -31123.03125  -31168.798828 -31221.792969 -31229.558594
#  -31281.537109 -31346.650391 -31364.503906 -31455.169922 -31488.013672
#  -31514.318359 -31538.580078 -31556.808594 -31561.115234 -31565.96875
# ...

# %%
x2, data2 = np.loadtxt('tutorial_gromacs/alanine_dip/pressure.xvg',comments=["#", "@"], unpack = True)
plt.plot(x2, data2)

# %%
x3, data3 = np.loadtxt('tutorial_gromacs/alanine_dip/temperature.xvg',comments=["#", "@"], unpack = True)
plt.plot(x3, data3)

# %%
x1_2, data1_2 = np.loadtxt('EXERCISE1/pressure.xvg',comments=["#", "@"], unpack = True)
plt.plot(x1_2, data1_2)

# %%
x2_2, data2_2 = np.loadtxt('EXERCISE1/temperature.xvg',comments=["#", "@"], unpack = True)
plt.plot(x2_2, data2_2)

# %%
x3_2, data3_2 = np.loadtxt('EXERCISE1/potential.xvg',comments=["#", "@"], unpack = True)
plt.plot(x3_2, data3_2)
